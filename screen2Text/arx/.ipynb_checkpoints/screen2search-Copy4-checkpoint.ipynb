# %% [markdown]
# # EXTRACTING TEXT FROM A SCREENSHOT
#
# and potentially feeding it to a search engine or (online) dictionary
#
# ### References:
#
# - <a href="https://tesseract-ocr.github.io/tessdoc/Home.html">Tesseract User Manual</a>
# - [Longdo Thai Dictionary](https://dict.longdo.com/search/)

# %%
# pip install pytesseract

from PIL import Image
from PIL import ImageGrab
import pytesseract
import requests as rq
from bs4 import BeautifulSoup as bs
from IPython.display import display
from IPython.display import HTML
import threading
from datetime import datetime as dt

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
print('>>> Likely imported.')
# Out:
# >>> Likely imported.

# %%
class ClipImg2Text:
    config_codes = """  0    Orientation and script detection (OSD) only.
      1    Automatic page segmentation with OSD.
      2    Automatic page segmentation, but no OSD, or OCR.
      3    Fully automatic page segmentation, but no OSD. (Default)
      4    Assume a single column of text of variable sizes.
      5    Assume a single uniform block of vertically aligned text.
      6    Assume a single uniform block of text.
      7    Treat the image as a single text line.
      8    Treat the image as a single word.
      9    Treat the image as a single word in a circle.
     10    Treat the image as a single character.
     11    Sparse text. Find as much text as possible in no particular order.
     12    Sparse text with OSD.
     13    Raw line. Treat the image as a single text line, bypassing hacks that are Tesseract-specific."""
    config_dict = {int(entry[0]): entry[1] for entry in [entry.strip().split('    ') for entry in config_codes.split('\n')]}
    corpus_path = r'F:\User\Learn\ไทยศึกษา\Lingvistics\lexitron_thai.txt'

    
    def __init__(self):
        self.im = None
        self.out_texts = {}
        self.validated_words = {}
        
    def grab(self):
        self.bim = None
        im = ImageGrab.grabclipboard()
        if im:
            self.im = im  # .convert("L")
        else:
            print('Looks like there was no image to grab. Please check the clipboard contents!')
        
    def binarize(self, skew=1):
        im = self.im.copy().convert("L")
        lightness = len(im.getdata()) / sum(im.getdata())
        threshold = sum(im.getextrema())/2 * skew
        xs, ys = im.size
        for x in range(xs):
            for y in range(ys):
                if im.getpixel((x, y)) > threshold:
                    px = 255 # if lightness > 0.25 else 0
                else:
                    px = 0 # if lightness > 0.25 else 255
                im.putpixel((x, y), px)
        return im
    
    def fan_binarize(self):
        self.bims = {}
        for skew in range(75,140,5):
            bim = self.binarize(skew/100)
            im.save(f'bims/{skew}.png')
            self.bims[skew] = im
    
    def recognize_original(self, lang='tha', config='--psm 7'):
        return pytesseract.image_to_string(self.im, config=config, lang=lang).strip() 
    
    def fan_recognize_original(self, lang='tha'):
        for code in list(self.config_dict.keys())[3:]:
            try:
                self.out_texts[code] = self.recognize_original(lang = lang, config=f'--psm {code}')
            except Exception as e:
                # texts[code] = e.__str__()
                continue
    
    def recognize_bin(self, skew=1, lang='tha', config='--psm 7'):
        bim = self.binarize(skew)
        return pytesseract.image_to_string(bim, config=config, lang=lang).strip()

    def fan_recognize_bin(self, lang='tha'):
        for code in list(self.config_dict.keys())[3:]:
            for skew in list(range(75,140,5)):
                key = code * 1000 + skew
                self.out_texts[key] = self.recognize_bin(skew/100, lang=lang, config=f'--psm {code}')
                
    def fan_recognize(self, lang, psm):
        """For given psm value, recognizing original image and binarized in a range of threshold skews"""
        res[psm] = self.recognize_original(lang=lang, config=f'--psm {psm}')
        for skew, image in self.bims.items():
            key = psm * 1000 + skew
            self.out_texts[key] = self.recognize_original(lang=lang, config=f'--psm {psm}')
        print(len(self.out_texts))
        
    def threads_recognize(self, lang, kind=None):
        """Recognizing the image, both original and binarized, in a range of psm values as per :kind:,
        appying a range of threshold skews as defined in `fan_recognize` for each psm value"""
        self.fan_binarize()
        lang = lang
        ex.out_texts.clear()
        psms = list(self.config_dict.keys())[3:]
        if kind == 'block':
            psms = (3, 4, 6, 11, 12, 13)
        if kind == 'line':
            psms = (3, 4, 6, 7, 11, 12, 13)
        threads = [threading.Thread(target=self.fan_recognize, args=(lang, psm), name=f't_{psm}') for psm in psms]
        for thread in threads:
            thread.start()
        for thread in threads:
            thread.join()
    
    def validate_words(self):
        self.validated_words.clear()
        with open(self.corpus_path, encoding='utf-8') as corpus:
            words = [line.strip() for line in corpus.readlines()]
            for key, word in self.out_texts.items():
                if word in words:
                    self.validated_words[key] = word
        freqs = {}
        for word in ex.validated_words.values():
            freqs[word] = freqs.get(word, 0) + 1
        total = sum(freqs.values())
        for key, val in freqs.items():
            freqs[key] = round(val/total, 2)
        return dict(sorted(freqs.items(), key=lambda item: item[1], reverse=True))

# %%
def lookup(text):
    dic_url = 'https://dict.longdo.com/search/'
    response = rq.get(dic_url + text, timeout=180)
    if not response.status_code == 200:
        print("Couldn't fetch.")
        return
    response.encoding = 'utf-8'
    soup = bs(response.text)
    headers = soup.find_all('td',  attrs={'class': 'search-table-header'})
    tables = soup.find_all('table', attrs={'class': 'search-result-table'})
    html='''<style>table {width: 60%;} </style>'''
    for header, table in zip(headers, tables):
        contents = header.text
        if not ('Subtitles' in contents or 'German-Thai:' in contents or 'French-Thai:' in contents):
            html += f'<h5>{header.text}<h5>'
            html += str(table).replace("black", "white")
    display(HTML(html))

# %%
ex = ClipImg2Text()

# %%
ex.grab()
ex.im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=91x89>

# %%
start = dt.now()
ex.threads_recognize('tha')
print(f'Done in {dt.now() - start}')
# Out:
# 21
# 42
# 63
# 84
# 105
# 126
# 147
# 168
# 189
# 210
# 231
# Done in 0:00:03.684995

# %%
for key in ex.out_texts.keys():
    text = ex.out_texts[key]
    if len(text) > 22 and '' in text:
        print(str(key) + ': \n')
        print(text)
        print('\n' * 3)
# Out:
# 7:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 7050:
#
# private static StringBuilder builder = new StringBuilder tH};
#
#
#
#
# 7055:
#
# private static StringBuilder builder = new StringBuilder(}|;
#
#
#
#
# 7060:
#
# Private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 7065:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 7070:
#
# private static StringBuilder builder = new StringBuilder()};
#
#
#
#
# 7075:
#
# private static StringBuilder builder = new StringBuilder()}
#
#
#
#
# 7080:
#
# private static StringBuilder builder = new StringBuilder()|:
#
#
#
#
# 7085:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 7090:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 7095:
#
# private static StringBuilder puiider = rew StringBuilder()|;
#
#
#
#
# 7100:
#
# pois sc is StringBuilder =1 StringBuilder ()|,
#
#
#
#
# 7105:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 7110:
#
# StringBuilder = StringBuilder()|
#
#
#
#
# 7115:
#
# StringBuilder = StringBuilder]
#
#
#
#
# 7120:
#
# StringBuilder = StringBuilder()]
#
#
#
#
# 7125:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 7130:
#
# StringBuilder = StringBuilder)
#
#
#
#
# 7135:
#
# SirirgBuitder = SorrrgBur er Q]
#
#
#
#
# 11:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 11050:
#
# private static StringBuilder builder = new StringBuilderfa};
#
#
#
#
# 11055:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 11060:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|
#
#
#
#
# 11065:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 11070:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 11075:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 11080:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder ()|;
#
#
#
#
# 11085:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder ()|;
#
#
#
#
# 11090:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 11095:
#
# private static StringBuilder hii
#
# ar
#
# StringBuilder()|;
#
#
#
#
# 11100:
#
# i
#
# StringBuilder
#
# =
#
# StringBuilder()|
#
#
#
#
# 11105:
#
# StringBuilder
#
# =
#
# StringBuilder{)
#
#
#
#
# 11110:
#
# StringBuilder
#
# =
#
# StringBuilder()
#
#
#
#
# 11115:
#
# =
#
# StringBuilder
#
# StringBuilder{)
#
#
#
#
# 11120:
#
# =
#
# StringBuilder
#
# StringBuilder{)]
#
#
#
#
# 11125:
#
# =
#
# StringBuilder
#
# StringBuilder{)|
#
#
#
#
# 11130:
#
# =
#
# StringBuilder
#
# StringBuilder)
#
#
#
#
# 11135:
#
# Siriraivitae
#
# SorrrgBur er Q]
#
#
#
#
# 13:
#
# ‘private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 13050:
#
# ‘private static StringBuilder builder = new StringBuilder;
#
#
#
#
# 13055:
#
# ‘private static StringBuilder builder = new StringBuilder()];
#
#
#
#
# 13060:
#
# ‘private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 13065:
#
# ‘private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 13070:
#
# ‘private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 13075:
#
# ‘private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 13080:
#
# private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 13085:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 13090:
#
# private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 13095:
#
# ‘private static StringBuilder puiider = rew StringBuilder ()|,
#
#
#
#
# 13100:
#
# oboe se is StringBuilder . 0%. = ve StringBuilder()|.
#
#
#
#
# 13105:
#
# StringBuilder = = StringBuilder()|
#
#
#
#
# 13110:
#
# StringBuilder == = StringBuilder()|
#
#
#
#
# 13115:
#
# StringBuilder == = StringBuilder Q)]|
#
#
#
#
# 13120:
#
# StringBuilder = = StringBuilder ()|
#
#
#
#
# 13125:
#
# StringBuilder = = StringBuilder ()|
#
#
#
#
# 13130:
#
# StringBuilder = StringBuilder ()]-
#
#
#
#
# 13135:
#
# Seirgfiuitder Se eegBur oer QQ]
#
#
#
#
# 3:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 3050:
#
# private static StringBuilder builder = new StringBuilder tH};
#
#
#
#
# 3055:
#
# private static StringBuilder builder = new StringBuilder(}|;
#
#
#
#
# 3060:
#
# Private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 3065:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 3070:
#
# private static StringBuilder builder = new StringBuilder()};
#
#
#
#
# 3075:
#
# private static StringBuilder builder = new StringBuilder()}
#
#
#
#
# 3080:
#
# private static StringBuilder builder = new StringBuilder()|:
#
#
#
#
# 3085:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 3090:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 3095:
#
# private static StringBuilder bui StringBuilder()|;
#
#
#
#
# 3100:
#
# i. StringBuilder StringBuilder()|,
#
#
#
#
# 3105:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 3110:
#
# StringBuilder = StringBuilder()|
#
#
#
#
# 3115:
#
# StringBuilder = StringBuilder]
#
#
#
#
# 3120:
#
# StringBuilder = StringBuilder()]
#
#
#
#
# 3125:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 3130:
#
# StringBuilder = StringBuilder)
#
#
#
#
# 3135:
#
# SirirgBuitder = SorrrgBur er Q]
#
#
#
#
# 6:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 6050:
#
# private static StringBuilder builder = new StringBuilder tH};
#
#
#
#
# 6055:
#
# private static StringBuilder builder = new StringBuilder(}|;
#
#
#
#
# 6060:
#
# Private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 6065:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 6070:
#
# private static StringBuilder builder = new StringBuilder()};
#
#
#
#
# 6075:
#
# private static StringBuilder builder = new StringBuilder()}
#
#
#
#
# 6080:
#
# private static StringBuilder builder = new StringBuilder()|:
#
#
#
#
# 6085:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 6090:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 6095:
#
# private static StringBuilder puiider = rew StringBuilder()|;
#
#
#
#
# 6100:
#
# pois sc is StringBuilder =1 StringBuilder ()|,
#
#
#
#
# 6105:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 6110:
#
# StringBuilder = StringBuilder()|
#
#
#
#
# 6115:
#
# StringBuilder = StringBuilder]
#
#
#
#
# 6120:
#
# StringBuilder = StringBuilder()]
#
#
#
#
# 6125:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 6130:
#
# StringBuilder = StringBuilder)
#
#
#
#
# 6135:
#
# SirirgBuitder = SorrrgBur er Q]
#
#
#
#
# 4:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 4050:
#
# private static StringBuilder builder = new StringBuilder tH};
#
#
#
#
# 4055:
#
# private static StringBuilder builder = new StringBuilder(}|;
#
#
#
#
# 4060:
#
# Private static StringBuilder builder = new StringBuilder()|
#
#
#
#
# 4065:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 4070:
#
# private static StringBuilder builder = new StringBuilder()};
#
#
#
#
# 4075:
#
# private static StringBuilder builder = new StringBuilder()}
#
#
#
#
# 4080:
#
# private static StringBuilder builder = new StringBuilder()|:
#
#
#
#
# 4085:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 4090:
#
# private static StringBuilder builder = new StringBuilder()|;
#
#
#
#
# 4095:
#
# private static StringBuilder bui StringBuilder()|;
#
#
#
#
# 4100:
#
# i. StringBuilder StringBuilder()|,
#
#
#
#
# 4105:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 4110:
#
# StringBuilder = StringBuilder()|
#
#
#
#
# 4115:
#
# StringBuilder = StringBuilder]
#
#
#
#
# 4120:
#
# StringBuilder = StringBuilder()]
#
#
#
#
# 4125:
#
# StringBuilder = StringBuilder{)|
#
#
#
#
# 4130:
#
# StringBuilder = StringBuilder)
#
#
#
#
# 4135:
#
# SirirgBuitder = SorrrgBur er Q]
#
#
#
#
# 12:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 12050:
#
# private static StringBuilder builder = new StringBuilderfa};
#
#
#
#
# 12055:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 12060:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|
#
#
#
#
# 12065:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 12070:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 12075:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 12080:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder ()|;
#
#
#
#
# 12085:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder ()|;
#
#
#
#
# 12090:
#
# =
#
# private static StringBuilder builder
#
# =
#
# new StringBuilder()|;
#
#
#
#
# 12095:
#
# private static StringBuilder hii
#
# StringBuilder()|;
#
#
#
#
# 12100:
#
# i
#
# StringBuilder
#
# -
#
# StringBuilder()|
#
#
#
#
# 12105:
#
# StringBuilder
#
# StringBuilder{)
#
#
#
#
# 12110:
#
# StringBuilder
#
# StringBuilder()
#
#
#
#
# 12115:
#
# StringBuilder
#
# StringBuilder{)
#
#
#
#
# 12120:
#
# StringBuilder
#
# StringBuilder{)]
#
#
#
#
# 12125:
#
# StringBuilder
#
# StringBuilder{)|
#
#
#
#
# 12130:
#
# StringBuilder
#
# StringBuilder)
#
#
#
#
# 12135:
#
# Siriraivitae
#
# SorrrgBur er Q]

# %%
text = ex.recognize_original(config='--psm 7')
text
# Out:
# 'เกสา'

# %%
ex.fan_recognize_original()
# ex.fan_recognize_bin()

# %%
suggestions = ex.validate_words()
suggestions
# Out:
# {'เกล้า': 0.3,
#  'เกศา': 0.23,
#  'เกล': 0.15,
#  'เกลา': 0.11,
#  'แง': 0.09,
#  'เจอ': 0.08,
#  'เอ้': 0.02,
#  'เจ': 0.02}

# %%
ex.validated_words
# Out:
# {9: 'ชา',
#  9110: 'เอย',
#  9115: 'เอย',
#  9130: 'อบ',
#  8: 'เอย',
#  8065: 'เอย',
#  8070: 'เอย',
#  8075: 'เอย',
#  8080: 'เอย',
#  8085: 'เอย',
#  8090: 'เอย',
#  8095: 'เอย',
#  8100: 'เอย',
#  8105: 'เอย',
#  8110: 'เอย',
#  8115: 'เอย',
#  8120: 'เอย',
#  8125: 'เอย',
#  7: 'เอย',
#  7065: 'เยิน',
#  7085: 'เอย',
#  7090: 'เอย',
#  7095: 'เอย',
#  7100: 'เอย',
#  7105: 'เอย',
#  7110: 'เอย',
#  7115: 'เอย',
#  7125: 'เอย',
#  7130: 'เอย',
#  3: 'เอย',
#  3065: 'เยิน',
#  3085: 'เอย',
#  3090: 'เอย',
#  3095: 'เอย',
#  3100: 'เอย',
#  3105: 'เอย',
#  3110: 'เอย',
#  3115: 'เอย',
#  3125: 'เอย',
#  3130: 'เอย',
#  6: 'เอย',
#  6065: 'เยิน',
#  6085: 'เอย',
#  6090: 'เอย',
#  6095: 'เอย',
#  6100: 'เอย',
#  6105: 'เอย',
#  6110: 'เอย',
#  6115: 'เอย',
#  6125: 'เอย',
#  6130: 'เอย',
#  13: 'เอย',
#  13065: 'เอย',
#  13070: 'เอย',
#  13075: 'เอย',
#  13080: 'เอย',
#  13085: 'เอย',
#  13090: 'เอย',
#  13095: 'เอย',
#  13100: 'เอย',
#  13105: 'เอย',
#  13110: 'เอย',
#  13115: 'เอย',
#  13120: 'เอย',
#  13125: 'เอย',
#  10: 'เอย',
#  10065: 'เยิน',
#  10085: 'เอย',
#  10090: 'เอย',
#  10095: 'เอย',
#  10100: 'เอย',
#  10105: 'เอย',
#  10110: 'เอย',
#  10115: 'เอย',
#  10125: 'เอย',
#  10130: 'เอย',
#  4: 'เอย',
#  4065: 'เยิน',
#  4085: 'เอย',
#  4090: 'เอย',
#  4095: 'เอย',
#  4100: 'เอย',
#  4105: 'เอย',
#  4110: 'เอย',
#  4115: 'เอย',
#  4125: 'เอย',
#  4130: 'เอย',
#  11: 'เอย',
#  11065: 'เยิน',
#  11085: 'เอย',
#  11090: 'เอย',
#  11095: 'เอย',
#  11100: 'เอย',
#  11105: 'เอย',
#  11110: 'เอย',
#  11115: 'เอย',
#  11125: 'เอย',
#  11130: 'เอย',
#  12: 'เอย',
#  12065: 'เยิน',
#  12085: 'เอย',
#  12090: 'เอย',
#  12095: 'เอย',
#  12100: 'เอย',
#  12105: 'เอย',
#  12110: 'เอย',
#  12115: 'เอย',
#  12125: 'เอย',
#  12130: 'เอย'}

# %%
keys = list(suggestions.keys())
if keys:
    top = keys[0]
    print(f'The best guess is "{top}" rated {suggestions[top]} out of {len(ex.validated_words)}')
    print(f'Others:')
    for i in range(1, len(suggestions)):
        print(f'{i} - {keys[i]} ({suggestions[keys[i]]})', end='\t')
    word = input('Enter to proceed with top-rated suggestion or number for other or word:')
    if not word:
        lookup(top)
    else:
        try:
            lookup(keys[int(word)])
        except:
            lookup(word)
# Out:
# The best guess is "เกล้า" rated 0.3 out of 53
# Others:
# 1 - เกศา (0.23)	2 - เกล (0.15)	3 - เกลา (0.11)	4 - แง (0.09)	5 - เจอ (0.08)	6 - เอ้ (0.02)	7 - เจ (0.02)
# Enter to proceed with top-rated suggestion or number for other or word:
# <style>table {width: 60%;} </style><h5>Thai-English: NECTEC's Lexitron-2 Dictionary [with local updates]<h5><table cellpadding="0" cellspacing="0" class="search-result-table" width="100%"><tr><td style="vertical-align:top;" width="150"><a href="search/เกล้า" style="color: white"><b>เกล้า</b></a></td><td style="vertical-align:top;">(v) wear hair in a bun or coil, <b>See also:</b> <a href="search/gather hair up">gather hair up</a>, <a href="search/dress a tuft of hair">dress a tuft of hair</a>, <a href="search/tie up hair in a bun">tie up hair in a bun</a>, <b>Syn.</b> <a href="search/รวบ">รวบ</a>, <a href="search/มุ่น">มุ่น</a>, <b>Ant.</b> <a href="search/ปล่อย">ปล่อย</a>, <b>Example:</b> ทางด้านวัฒนธรรม ชาวผู้ไทสวมเครื่องประดับ สร้อยข้อมือ ข้อเท้าด้วยโลหะเงิน เกล้าผมมวยสูงตั้งตรง มัดมวยด้วยผ้าแถบผืนเล็กๆ, <b>Thai Definition:</b> มุ่นผมให้เรียบร้อย</td></tr><tr><td style="vertical-align:top;" width="150"><a href="search/เกล้า" style="color: white"><b>เกล้า</b></a></td><td style="vertical-align:top;">(n) head, <b>See also:</b> <a href="search/skull">skull</a>, <b>Syn.</b> <a href="search/หัว">หัว</a>, <a href="search/กระหม่อม">กระหม่อม</a>, <a href="search/เศียร">เศียร</a>, <a href="search/ ศีรษะ"> ศีรษะ</a>, <b>Example:</b> การลงภาพบุคคลในสถาบันที่สาธารณชนเคารพสักการะและนับถือไว้เหนือเกล้าเหนือหัวนั้นควรระมัดระวังความเสื่อมเสียหายให้มาก, <b>Count Unit:</b> หัว</td></tr></table><h5>ไทย-ไทย: พจนานุกรมฉบับราชบัณฑิตยสถาน พ.ศ. ๒๕๕๔<h5><table cellpadding="0" cellspacing="0" class="search-result-table" width="100%"><tr><td style="vertical-align:top;" width="150"><a href="search/เกล้า" style="color: white"><b>เกล้า</b></a></td><td style="vertical-align:top;">(เกฺล้า) น. หัว (ใช้เฉพาะในโวหารแสดงความเคารพอย่างสูง) เช่น มารดาบังเกิด<b>เกล้า</b>.</td></tr><tr><td style="vertical-align:top;" width="150"><a href="search/เกล้า" style="color: white"><b>เกล้า</b></a></td><td style="vertical-align:top;">(เกฺล้า) ก. มุ่นผมให้เรียบร้อย เช่น <b>เกล้า</b>จุก <b>เกล้า</b>มวย.</td></tr></table><h5>Thai-English-French: Volubilis Dictionary 1.0<h5><table cellpadding="0" cellspacing="0" class="search-result-table" width="100%"><tr><td style="vertical-align:top;" width="150"><a href="search/เกล้า" style="color: white"><b>เกล้า</b></a></td><td>[klāo] (n) <b>EN:</b> crown of the head ; head ; skull</td></tr><tr><td style="vertical-align:top;" width="150"><a href="search/เกล้า" style="color: white"><b>เกล้า</b></a></td><td>[klāo] (v) <b>EN:</b> wear hair in a bun or coil ; gather hair up ; dress a tuft of hair ; tie up hair in a bun</td></tr></table><h5>English-Thai: HOPE Dictionary [with local updates]<h5><table cellpadding="0" cellspacing="0" class="search-result-table" width="100%"><tr><td style="vertical-align:top;" width="150"><a href="search/bloodcurdling" style="color: white">bloodcurdling</a></td><td style="vertical-align:top;">adj. ขนพอง, สยอง<b>เกล้า</b>, น่ากลัวมาก</td></tr><tr><td style="vertical-align:top;" width="150"><a href="search/coronet" style="color: white">coronet</a></td><td style="vertical-align:top;">(คอ'ระนิท) n. มงกุฎเล็ก, รัด<b>เกล้า</b>ของสตรี</td></tr><tr><td style="vertical-align:top;" width="150"><a href="search/diadem" style="color: white">diadem</a></td><td style="vertical-align:top;">(ได'อะเดม) n., vt. (ใส่) มงกุฎ, รัด<b>เกล้า</b>, พระราชอำนาจ, พระฐานันดรศักดิ์., <b>Syn.</b> crown</td></tr></table><h5>English-Thai: Nontri Dictionary<h5><table cellpadding="0" cellspacing="0" class="search-result-table" width="100%"><tr><td style="vertical-align:top;" width="150"><a href="search/bloodcurdling" style="color: white">bloodcurdling</a></td><td style="vertical-align:top;">(adj) น่ากลัวมาก, น่าขนพองสยอง<b>เกล้า</b></td></tr><tr><td style="vertical-align:top;" width="150"><a href="search/circlet" style="color: white">circlet</a></td><td style="vertical-align:top;">(n) วงแหวน, รัด<b>เกล้า</b></td></tr><tr><td style="vertical-align:top;" width="150"><a href="search/coronet" style="color: white">coronet</a></td><td style="vertical-alig ...

# %%
lookup('ฮํา')
# Out:
# <style>table {width: 60%;} </style>
